# %%
# !pip install accelerate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting accelerate
#   Downloading accelerate-0.15.0-py3-none-any.whl (191 kB)
#      |████████████████████████████████| 191 kB 17.8 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from accelerate) (21.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from accelerate) (6.0)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from accelerate) (1.13.0+cu116)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from accelerate) (1.21.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from accelerate) (5.4.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->accelerate) (3.0.9)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.4.0->accelerate) (4.4.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.15.0

# %%
# !pip install -U stable_diffusion_videos
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting stable_diffusion_videos
#   Downloading stable_diffusion_videos-0.7.1-py3-none-any.whl (26 kB)
# Collecting gradio
#   Downloading gradio-3.14.0-py3-none-any.whl (13.8 MB)
#      |████████████████████████████████| 13.8 MB 164 kB/s
# Collecting av<10.0.0
#   Downloading av-9.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28.8 MB)
#      |████████████████████████████████| 28.8 MB 94.5 MB/s
# Collecting transformers>=4.21.0
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 59.4 MB/s
# Collecting fire
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 11.1 MB/s
# Collecting diffusers==0.9.0
#   Downloading diffusers-0.9.0-py3-none-any.whl (453 kB)
#      |████████████████████████████████| 453 kB 75.4 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from stable_diffusion_videos) (1.7.3)
# Requirement already satisfied: librosa in /usr/local/lib/python3.8/dist-packages (from stable_diffusion_videos) (0.8.1)
# Collecting realesrgan==0.2.5.0
#   Downloading realesrgan-0.2.5.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from diffusers==0.9.0->stable_diffusion_videos) (2.23.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (from diffusers==0.9.0->stable_diffusion_videos) (7.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from diffusers==0.9.0->stable_diffusion_videos) (2022.6.2)
# Collecting huggingface-hub>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 53.5 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from diffusers==0.9.0->stable_diffusion_videos) (4.13.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from diffusers==0.9.0->stable_diffusion_videos) (3.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from diffusers==0.9.0->stable_diffusion_videos) (1.21.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from realesrgan==0.2.5.0->stable_diffusion_videos) (4.64.1)
# Collecting gfpgan>=0.2.1
#   Downloading gfpgan-1.3.8-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 942 kB/s
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.8/dist-packages (from realesrgan==0.2.5.0->stable_diffusion_videos) (1.13.0+cu116)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from realesrgan==0.2.5.0->stable_diffusion_videos) (0.14.0+cu116)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.8/dist-packages (from realesrgan==0.2.5.0->stable_diffusion_videos) (4.6.0.66)
# Collecting basicsr>=1.3.3.11
#   Downloading basicsr-1.4.2.tar.gz (172 kB)
#      |████████████████████████████████| 172 kB 61.3 MB/s
# Collecting facexlib>=0.2.0.3
#   Downloading facexlib-0.2.5-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 4.3 MB/s
# Collecting addict
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (0.16.0)
# Requirement already satisfied: lmdb in /usr/local/lib/python3.8/dist-packages (from basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (0.99)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (6.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.8/dist-packages (from basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (0.18.3)
# Collecting tb-nightly
#   Downloading tb_nightly-2.12.0a20221214-py3-none-any.whl (5.7 MB)
#      |████████████████████████████████| 5.7 MB 73.8 MB/s
# Collecting yapf
#   Downloading yapf-0.32.0-py2.py3-none-any.whl (190 kB)
#      |████████████████████████████████| 190 kB 83.2 MB/s
# Collecting filterpy
#   Downloading filterpy-1.4.5.zip (177 kB)
#      |████████████████████████████████| 177 kB 64.6 MB/s
# Requirement already satisfied: numba in /usr/local/lib/python3.8/dist-packages (from facexlib>=0.2.0.3->realesrgan==0.2.5.0->stable_diffusion_videos) (0.56.4)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.9.0->stable_diffusion_videos) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.9.0->stable_diffusion_videos) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.9->huggingface-hub>=0.10.0->diffusers==0.9.0->stable_diffusion_videos) (3.0.9)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 70.9 MB/s
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from filterpy->facexlib>=0.2.0.3->realesrgan==0.2.5.0->stable_diffusion_videos) (3.2.2)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from fire->stable_diffusion_videos) (1.15.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.8/dist-packages (from fire->stable_diffusion_videos) (2.1.1)
# Collecting pycryptodome
#   Downloading pycryptodome-3.16.0-cp35-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 71.0 MB/s
# Collecting fastapi
#   Downloading fastapi-0.88.0-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 4.0 MB/s
# Collecting markdown-it-py[linkify,plugins]
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 3.4 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from gradio->stable_diffusion_videos) (1.3.5)
# Requirement already satisfied: altair in /usr/local/lib/python3.8/dist-packages (from gradio->stable_diffusion_videos) (4.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from gradio->stable_diffusion_videos) (2.11.3)
# Collecting httpx
#   Downloading httpx-0.23.1-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 4.9 MB/s
# Collecting python-multipart
#   Downloading python-multipart-0.0.5.tar.gz (32 kB)
# Collecting websockets>=10.0
#   Downloading websockets-10.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      |████████████████████████████████| 106 kB 57.0 MB/s
# Collecting orjson
#   Downloading orjson-3.8.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (278 kB)
#      |████████████████████████████████| 278 kB 67.7 MB/s
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.8/dist-packages (from gradio->stable_diffusion_videos) (2.0.1)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.8/dist-packages (from gradio->stable_diffusion_videos) (1.10.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from gradio->stable_diffusion_videos) (3.8.3)
# Collecting uvicorn
#   Downloading uvicorn-0.20.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 5.7 MB/s
# Collecting ffmpy
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.8/dist-packages (from gradio->stable_diffusion_videos) (2022.11.0)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio->stable_diffusion_videos) (6.0.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio->stable_diffusion_videos) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio->stable_diffusion_videos) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio->stable_diffusion_videos) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio->stable_diffusion_videos) (2.1.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio->stable_diffusion_videos) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio->stable_diffusion_videos) (1.8.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.8/dist-packages (from yarl<2.0,>=1.0->aiohttp->gradio->stable_diffusion_videos) (2.10)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.8/dist-packages (from altair->gradio->stable_diffusion_videos) (4.3.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.8/dist-packages (from altair->gradio->stable_diffusion_videos) (0.12.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.8/dist-packages (from altair->gradio->stable_diffusion_videos) (0.4)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair->gradio->stable_diffusion_videos) (5.10.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair->gradio->stable_diffusion_videos) (0.19.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema>=3.0->altair->gradio->stable_diffusion_videos) (3.11.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->gradio->stable_diffusion_videos) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->gradio->stable_diffusion_videos) (2022.6)
# Collecting starlette==0.22.0
#   Downloading starlette-0.22.0-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.8 MB/s
# Collecting anyio<5,>=3.4.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 12.5 MB/s
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.2-py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 8.6 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from httpx->gradio->stable_diffusion_videos) (2022.9.24)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 7.7 MB/s
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.8/dist-packages (from librosa->stable_diffusion_videos) (1.6.0)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.8/dist-packages (from librosa->stable_diffusion_videos) (0.11.0)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from librosa->stable_diffusion_videos) (0.4.2)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from librosa->stable_diffusion_videos) (4.4.2)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from librosa->stable_diffusion_videos) (1.0.2)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from librosa->stable_diffusion_videos) (3.0.0)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.8/dist-packages (from librosa->stable_diffusion_videos) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba->facexlib>=0.2.0.3->realesrgan==0.2.5.0->stable_diffusion_videos) (57.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba->facexlib>=0.2.0.3->realesrgan==0.2.5.0->stable_diffusion_videos) (0.39.1)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from pooch>=1.0->librosa->stable_diffusion_videos) (1.4.4)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->diffusers==0.9.0->stable_diffusion_videos) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->diffusers==0.9.0->stable_diffusion_videos) (1.24.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa->stable_diffusion_videos) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.8/dist-packages (from soundfile>=0.10.2->librosa->stable_diffusion_videos) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa->stable_diffusion_videos) (2.21)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting mdit-py-plugins
#   Downloading mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 8.7 MB/s
# Collecting linkify-it-py~=1.0
#   Downloading linkify_it_py-1.0.3-py3-none-any.whl (19 kB)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->filterpy->facexlib>=0.2.0.3->realesrgan==0.2.5.0->stable_diffusion_videos) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->filterpy->facexlib>=0.2.0.3->realesrgan==0.2.5.0->stable_diffusion_videos) (0.11.0)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image->basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (2.8.8)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from scikit-image->basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (1.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.8/dist-packages (from scikit-image->basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (2022.10.10)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image->basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (2.9.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tb-nightly->basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (1.3.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tb-nightly->basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (1.51.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tb-nightly->basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tb-nightly->basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tb-nightly->basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (0.38.4)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tb-nightly->basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tb-nightly->basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tb-nightly->basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (2.15.0)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tb-nightly->basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (3.19.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tb-nightly->basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tb-nightly->basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tb-nightly->basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tb-nightly->basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tb-nightly->basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tb-nightly->basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tb-nightly->basicsr>=1.3.3.11->realesrgan==0.2.5.0->stable_diffusion_videos) (3.2.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.8/dist-packages (from uvicorn->gradio->stable_diffusion_videos) (7.1.2)
# Building wheels for collected packages: basicsr, filterpy, fire, ffmpy, python-multipart
#   Building wheel for basicsr (setup.py) ... done
#   Created wheel for basicsr: filename=basicsr-1.4.2-py3-none-any.whl size=214838 sha256=964dd3dfbddddae951069cd666c0b6795759b0c86e7a6efd2b40bdc674d345ca
#   Stored in directory: /root/.cache/pip/wheels/4d/d3/95/e17d0bcdd7dcfb0dbf79db006711e434c42036efbf6695ef7f
#   Building wheel for filterpy (setup.py) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110474 sha256=4ec6fa5d3187a3326d68b0710da0f48fbf0ea1cfe04b3e5b8a0a0632d0e8bb5d
#   Stored in directory: /root/.cache/pip/wheels/fe/f6/cb/40331472edf4fd399b8cad02973c6acbdf26898342928327fe
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116949 sha256=ad6904a0c852b6b57eea1ad4e32308fb06f50b564ae974c10189721810bd5df1
#   Stored in directory: /root/.cache/pip/wheels/5b/eb/43/7295e71293b218ddfd627f935229bf54af9018add7fbb5aac6
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4711 sha256=82908979d5eae38622692a2c618769c027a22aa50705be6a06f1ae057e45b31f
#   Stored in directory: /root/.cache/pip/wheels/ff/5b/59/913b443e7369dc04b61f607a746b6f7d83fb65e2e19fcc958d
#   Building wheel for python-multipart (setup.py) ... done
#   Created wheel for python-multipart: filename=python_multipart-0.0.5-py3-none-any.whl size=31678 sha256=6836d3811d3be715ce98f76636f202d50a19674361578ed5dff82d4f2b271322
#   Stored in directory: /root/.cache/pip/wheels/9e/fc/1c/cf980e6413d3ee8e70cd8f39e2366b0f487e3e221aeb452eb0
# Successfully built basicsr filterpy fire ffmpy python-multipart
# Installing collected packages: sniffio, mdurl, yapf, uc-micro-py, tb-nightly, rfc3986, markdown-it-py, h11, filterpy, anyio, addict, starlette, mdit-py-plugins, linkify-it-py, httpcore, facexlib, basicsr, websockets, uvicorn, tokenizers, python-multipart, pydub, pycryptodome, orjson, huggingface-hub, httpx, gfpgan, ffmpy, fastapi, transformers, realesrgan, gradio, fire, diffusers, av, stable-diffusion-videos
# Successfully installed addict-2.4.0 anyio-3.6.2 av-9.2.0 basicsr-1.4.2 diffusers-0.9.0 facexlib-0.2.5 fastapi-0.88.0 ffmpy-0.3.0 filterpy-1.4.5 fire-0.5.0 gfpgan-1.3.8 gradio-3.14.0 h11-0.14.0 httpcore-0.16.2 httpx-0.23.1 huggingface-hub-0.11.1 linkify-it-py-1.0.3 markdown-it-py-2.1.0 mdit-py-plugins-0.3.3 mdurl-0.1.2 orjson-3.8.3 pycryptodome-3.16.0 pydub-0.25.1 python-multipart-0.0.5 realesrgan-0.2.5.0 rfc3986-1.5.0 sniffio-1.3.0 stable-diffusion-videos-0.7.1 starlette-0.22.0 tb-nightly-2.12.0a20221214 tokenizers-0.13.2 transformers-4.25.1 uc-micro-py-1.0.1 uvicorn-0.20.0 websockets-10.4 yapf-0.32.0

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.huggingface/token
# Login successful

# %%
from stable_diffusion_videos import StableDiffusionWalkPipeline, Interface
import torch

pipeline = StableDiffusionWalkPipeline.from_pretrained(
    "CompVis/stable-diffusion-v1-4",
    torch_dtype=torch.float16,
    revision="fp16",
).to("cuda")

interface = Interface(pipeline)
interface.launch(share=True)
# Out:
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/gradio/blocks.py:717: UserWarning: api_name predict already exists, using predict_1
#   warnings.warn(
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
#
# Setting up a public link... we have recently upgraded the way public links are generated. If you encounter any problems, please report the issue and downgrade to gradio version 3.13.0
# .
# Running on public URL: https://a57aca8b-8e16-4625.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://a57aca8b-8e16-4625.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
